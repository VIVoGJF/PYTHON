# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
df['salary_year_avg'].median()
# Out:
# np.float64(15000.0)

# %%
df['salary_year_avg'].min()
# Out:
# np.float64(15000.0)

# %%
minidx = df['salary_year_avg'].idxmin()
df.iloc[minidx]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# salary_year_avg                                                    15000.0
# salary_hour_avg                                                        NaN
# company_name                                               Net2Source Inc.
# job_skills               ['java', 'python', 'oracle', 'aws', 'hadoop', ...
# job_type_skills          {'cloud': ['oracle', 'aws'], 'libraries': ['ha...
# Name: 665729, dtype: object

# %%
df.groupby(['job_title_short'])[['salary_year_avg','salary_hour_avg']].agg(['min','max','median'])
# Out:
#                           salary_year_avg            ... salary_hour_avg
#                                       min       max  ...             max     median
# job_title_short                                      ...
# Business Analyst                  16500.0  387460.0  ...           132.5  40.362499
# Cloud Engineer                    42000.0  280000.0  ...            91.0  40.000000
# Data Analyst                      25000.0  650000.0  ...           391.0  32.615002
# Data Engineer                     15000.0  525000.0  ...           184.5  58.500000
# Data Scientist                    27000.0  960000.0  ...           237.5  47.500000
# Machine Learning Engineer         30000.0  325000.0  ...            87.5  47.535000
# Senior Data Analyst               30000.0  425000.0  ...           130.0  47.500000
# Senior Data Engineer              35000.0  425000.0  ...           170.0  61.500000
# Senior Data Scientist             45000.0  890000.0  ...           150.0  47.620003
# Software Engineer                 28000.0  375000.0  ...           102.5  47.560001
#
# [10 rows x 6 columns]
